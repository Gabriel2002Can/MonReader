# %% [markdown]
# # Computer Vision Project

# %% [markdown]
# ## Importing Modules

# %%
import matplotlib.pyplot as plt
import random
from sklearn.metrics import f1_score, accuracy_score, roc_auc_score, roc_curve, auc, confusion_matrix, ConfusionMatrixDisplay, classification_report

import tensorflow as tf
import keras

datasets = keras.datasets
layers = keras.layers
models = keras.models

from tensorflow.keras.models import load_model

print("imported")
# Out:
# imported

# %% [markdown]
# ## Importing Data

# %%
# Path to image folder
images_dir = "images"

# Defining paramethers
img_size = (128, 128)
batch_size = 32
seed = 123

# Defining datasets

# Training Dataset
dataset_training = tf.keras.utils.image_dataset_from_directory(
    images_dir + "/training",
    validation_split=0.2,
    subset="training",
    seed=seed,
    image_size=img_size,
    batch_size=batch_size
)

# Validation Dataset
dataset_validation = tf.keras.utils.image_dataset_from_directory(
    images_dir + "/training",
    validation_split=0.2,
    subset="validation",
    seed=seed,
    image_size=img_size,
    batch_size=batch_size
)

# Test Dataset
dataset_test = tf.keras.utils.image_dataset_from_directory(
    images_dir + "/testing",
    seed=seed,
    image_size=img_size,
    batch_size=batch_size
)
# Out:
# Found 2392 files belonging to 2 classes.
# Using 1914 files for training.
# Found 2392 files belonging to 2 classes.
# Using 478 files for validation.
# Found 597 files belonging to 2 classes.

# %% [markdown]
# ## Exploring the Dataset

# %%
print(dataset_training.class_names)
# Out:
# ['flip', 'notflip']

# %% [markdown]
# Printing the classes for imagens on the Dataset.

# %% [markdown]
# ### Image Examples

# %%
# Show one example image per class for both training and test datasets

class_names = dataset_training.class_names
n_classes_to_show = min(2, len(class_names))  

# Defining function that gets exemples of images for both classes
def get_examples_by_class(ds, n_classes=2, max_batches=20):
    examples = {i: None for i in range(n_classes)}
    found = 0

    for images, labels in ds.take(max_batches):
        labels_np = labels.numpy()
        for i in range(images.shape[0]):
            cls = int(labels_np[i])
            if cls < n_classes and examples[cls] is None:
                examples[cls] = images[i].numpy().astype("uint8")
                found += 1
                if found == n_classes:
                    return examples
    return examples

# Getting examples for both the train and test classes
train_examples = get_examples_by_class(dataset_training, n_classes=n_classes_to_show)
test_examples = get_examples_by_class(dataset_test, n_classes=n_classes_to_show)

fig, axes = plt.subplots(2, n_classes_to_show, figsize=(4 * n_classes_to_show, 8))

for cls_idx in range(n_classes_to_show):
    
    # Training row
    ax = axes[0, cls_idx] if n_classes_to_show > 1 else axes[0]
    img = train_examples[cls_idx]
    if img is not None:
        ax.imshow(img)
    ax.set_title(f"Train - {class_names[cls_idx]}")
    ax.axis("off")

    # Test row
    ax = axes[1, cls_idx] if n_classes_to_show > 1 else axes[1]
    img = test_examples[cls_idx]
    if img is not None:
        ax.imshow(img)
    ax.set_title(f"Test - {class_names[cls_idx]}")
    ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# This shows examples of images on both the Training and Test datasets and their respective classes. These images where resized, so that is why the images can be a bit pixelated.

# %% [markdown]
# ### Class Distribution

# %%
# Defining function that counts the quantity of images for each class. It stores the information in a dictionary
def counting_number_records(ds):
    values = {}

    for images, labels in ds:
        labels = labels.numpy()  

        for label in labels:
            label = int(label)
            if label not in values:
                values[label] = 0
            values[label] += 1
    
    return values

# %%
counting_training = counting_number_records(dataset_training) 

counting_test = counting_number_records(dataset_test) 

class_names = dataset_training.class_names

# %%
print('The Training Dataset:')

for label, count in counting_training.items():
    print(f'{class_names[label]} has {count} records')
# Out:
# The Training Dataset:
# flip has 928 records
# notflip has 986 records

# %%
print('The Test Dataset:')

for label, count in counting_test.items():
    print(f'{class_names[label]} has {count} records')
# Out:
# The Test Dataset:
# flip has 290 records
# notflip has 307 records

# %%
# Prints a graph of the class distribution for the training set

labels = ['flip','not flip']

fig = plt.subplots(1, 1, figsize=(6, 6))

def make_autopct(values):
    def my_autopct(pct):
        absolute = int(round(pct / 100. * sum(values)))
        return f'{pct:.1f}%\n({absolute})'
    return my_autopct

plt.pie(counting_training.values(), labels=labels, autopct=make_autopct(counting_training.values()))

plt.title('Class Distribution')
# Out:
# Text(0.5, 1.0, 'Class Distribution')

# %% [markdown]
# This Pie graph shows that the class distribution is fairly well balanced, meaning that we won't have to worry much about class weights and samplings.

# %% [markdown]
# ## NeuralNets

# %% [markdown]
# ### Data Processing

# %%
# Rescaling tensors to be between 0 - 1 (Normalizing)
rescaling_layer = tf.keras.layers.Rescaling(1./255)

dataset_training = dataset_training.map(lambda x, y: (rescaling_layer(x), y))
dataset_validation = dataset_validation.map(lambda x, y: (rescaling_layer(x), y))
dataset_test = dataset_test.map(lambda x, y: (rescaling_layer(x), y))

# %%
# Configuring cache for faster operations
dataset_training = dataset_training.cache()
dataset_validation = dataset_validation.cache()
dataset_test = dataset_test.cache()

# %% [markdown]
# ### NeuralNet Implementation

# %%
# Preparing for data augmentation, it should reduce overfitting
data_augmentation = tf.keras.Sequential([
  tf.keras.layers.RandomFlip('horizontal'),
  tf.keras.layers.RandomRotation(0.2),
])

# %% [markdown]
# #### NeuralNet Definition

# %%
# Configuring NeuralNet

# Setting Batch Size
size = 128

# Setting seed
random.seed(0)

model = models.Sequential()

# Adding First Convolutional Layer; The initial input shape is necessary for determining the expected tensor
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(size, size, 3))) # Using a Kernel of 3x3; Smaller Kernels will reduce the processing time and will increase detail capturing

# All Max Pooling layers will be 2x2, to reduce processing time and complexity
model.add(layers.MaxPooling2D((2, 2)))

# Dropout should help reduce overfitting
model.add(layers.Dropout(0.25))

# Second Convolutional Layer
model.add(layers.Conv2D(64, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Dropout(0.25))

# Third Convolutional Layer
model.add(layers.Conv2D(128, (3, 3), activation='relu', kernel_regularizer=tf.keras.regularizers.l2(0.01)))

# Flattening Tensor for dense operations
model.add(layers.Flatten())

# Dense operation outputing 128 features extracted from the CNN
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dropout(0.25))

# Produces the final output (binary)
model.add(layers.Dense(1))
# Out:
# C:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Defining Learning optimizer (Adam and the learning rate)
# Defining Loss function 
# Defining the metric
lr = 0.001
model.compile(optimizer=tf.keras.optimizers.Adam(lr),
              loss=tf.keras.losses.BinaryCrossentropy(from_logits=True),
              metrics=['accuracy'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %% [markdown]
# #### Training

# %%
# Initiating training with a number of epochs
epochs=30
history = model.fit(
  dataset_training,
  validation_data=dataset_validation,
  epochs=epochs,
  verbose=1
)
# Out:
# Epoch 1/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 23s 361ms/step - accuracy: 0.4916 - loss: 1.7933 - val_accuracy: 0.4895 - val_loss: 1.2733
# Epoch 2/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 17s 289ms/step - accuracy: 0.5266 - loss: 1.1433 - val_accuracy: 0.5502 - val_loss: 1.0703
# Epoch 3/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 320ms/step - accuracy: 0.5935 - loss: 0.9450 - val_accuracy: 0.6841 - val_loss: 0.8507
# Epoch 4/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 316ms/step - accuracy: 0.8051 - loss: 0.6828 - val_accuracy: 0.8577 - val_loss: 0.5667
# Epoch 5/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 18s 305ms/step - accuracy: 0.9091 - loss: 0.4520 - val_accuracy: 0.9100 - val_loss: 0.4076
# Epoch 6/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 20s 333ms/step - accuracy: 0.9545 - loss: 0.3159 - val_accuracy: 0.9498 - val_loss: 0.3054
# Epoch 7/30
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 19s 317ms/step - accuracy: 0.9718 - loss: 0.2400 - val_accuracy: 0.9665 - val_loss: 0.2321
# Epoch 8/30
# ...

# %%
# Saving the model in a .keras file
model_path = "monreader_model.keras"
model.save(model_path)
print(f"Model saved as {model_path}")
# Out:
# Model saved as monreader_model.keras

# %% [markdown]
# ## Evaluation

# %%
# Loading Model from the keras file
model = load_model("monreader_model.keras")

# %% [markdown]
# ### Training Set

# %%
# Get predictions on training dataset
y_true = []
y_pred = []

for images, labels in dataset_training:
    predictions = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend((predictions > 0.5).astype(int).flatten())

# Calculate metrics
training_accuracy = accuracy_score(y_true, y_pred)
training_f1 = f1_score(y_true, y_pred)

print(f"Training Accuracy: {training_accuracy:.4f}")
print(f"Training F1 Score: {training_f1:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# ...

# %% [markdown]
# #### Accuracy and F1

# %%
# Plotting Accuracy and F1 graph for the Training Set
plt.figure(figsize=(10, 6))

metrics = ['Accuracy', 'F1 Score']
scores = [training_accuracy, training_f1]

bars = plt.bar(metrics, scores, color=['#2ecc71', '#3498db'], width=0.6)

# Add value labels on bars
for bar, score in zip(bars, scores):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{score:.4f}',
             ha='center', va='bottom', fontsize=12, fontweight='bold')

plt.ylim(0, 1)
plt.ylabel('Score', fontsize=12)
plt.title('Training Dataset Performance Metrics', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

print(f"\nTraining Set Performance Summary:")
print(f"  Accuracy: {training_accuracy:.4f}")
print(f"  F1 Score: {training_f1:.4f}")
# Out:
# Training Set Performance Summary:
#   Accuracy: 1.0000
#   F1 Score: 1.0000

# %% [markdown]
# Both **accuracy** and **F1 score** reach **100%** on the **training set**. While this can sometimes indicate overfitting, the training and validation curves remain stable across epochs, without signs of divergence or instability in the loss. This suggests the model is able to fit the training distribution effectively without immediate signs of optimization issues. However, training performance alone is not sufficient to assess generalization, so evaluation on the test set is required.

# %% [markdown]
# #### Classification Report

# %%
# Generating evaluating metrics
classification_training = classification_report(y_true, y_pred)
conf_matrix_training = confusion_matrix(y_true, y_true)

print(f'Classification Report Training Set: \n{classification_training}')
# Out:
# Classification Report Training Set:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       928
#            1       1.00      1.00      1.00       986
#
#     accuracy                           1.00      1914
#    macro avg       1.00      1.00      1.00      1914
# weighted avg       1.00      1.00      1.00      1914

# %% [markdown]
# The classification report shows **perfect precision, recall, and F1-score (1.00) for both classes**. This indicates that the model correctly identifies all positive and negative samples in the training set without any misclassification. Additionally, both macro and weighted averages are equal to 1.00, confirming balanced performance across classes and no bias toward a specific label.

# %% [markdown]
# #### Confusion Matrix

# %%
# Printing the Confusion Matrix
display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_training, display_labels=['0', '1'])
plt.figure(figsize=(8, 6))
display.plot(cmap=plt.cm.Reds)
plt.title('Confusion Matrix Training Set')
plt.show()

# %% [markdown]
# The confusion matrix is perfectly diagonal, meaning:
#
# - **All instances of class 0 are correctly classified as class 0**
# - **All instances of class 1 are correctly classified as class 1**
#
# There are no false positives or false negatives, reinforcing that the model achieves perfect performance on the training data.

# %% [markdown]
# #### ROC and AUC

# %%
# Getting AUC score
auc_score = roc_auc_score(y_true, y_pred)

print(f"AUC: {auc_score:.4f}")

# Calculating FPR, TPR e thresholds
fpr, tpr, thresholds = roc_curve(y_true, y_pred)

# Plot
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2,
         label=f'ROC curve (AUC = {auc_score:.3f})')
plt.plot([0, 1], [0, 1], color='b', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# AUC: 1.0000

# %% [markdown]
# The ROC curve reaches the top-left corner of the plot, corresponding to a True Positive Rate (TPR) of 1 and False Positive Rate (FPR) of 0. This results in an AUC (Area Under the Curve) of 1.0, which represents perfect class separability. In practical terms, **the model is able to completely distinguish between the two classes in the training set**.

# %% [markdown]
# ### Test Set

# %%
# Get predictions on test dataset
y_true = []
y_pred = []

for images, labels in dataset_test:
    predictions = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend((predictions > 0.5).astype(int).flatten())

# Calculate metrics
test_accuracy = accuracy_score(y_true, y_pred)
test_f1 = f1_score(y_true, y_pred)

print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"Test F1 Score: {test_f1:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# Test Accuracy: 0.9933
# Test F1 Score: 0.9935

# %% [markdown]
# #### Accuracy and F1

# %%
# Plotting Accuracy and F1 graph for the Test Set
plt.figure(figsize=(10, 6))

metrics = ['Accuracy', 'F1 Score']
scores = [test_accuracy, test_f1]

bars = plt.bar(metrics, scores, color=['#2ecc71', '#3498db'], width=0.6)

# Add value labels on bars
for bar, score in zip(bars, scores):
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{score:.4f}',
             ha='center', va='bottom', fontsize=12, fontweight='bold')

plt.ylim(0, 1)
plt.ylabel('Score', fontsize=12)
plt.title('Test Dataset Performance Metrics', fontsize=14, fontweight='bold')
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

print(f"\nTest Set Performance Summary:")
print(f"  Accuracy: {test_accuracy:.4f}")
print(f"  F1 Score: {test_f1:.4f}")
# Out:
# Test Set Performance Summary:
#   Accuracy: 0.9933
#   F1 Score: 0.9935

# %% [markdown]
# The test **accuracy and F1 score remain very high** and closely match the training performance. This consistency indicates **strong generalization** and no significant evidence of overfitting under the current dataset split. The model appears to learn features that transfer well to unseen data within the same distribution.

# %% [markdown]
# #### Classification Report

# %%
# Generating evaluating metrics
classification_test = classification_report(y_true, y_pred)
conf_matrix_test = confusion_matrix(y_true, y_pred)

print(f'Classification Report Test Set: \n{classification_training}')
# Out:
# Classification Report Test Set:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       290
#            1       1.00      0.99      0.99       307
#
#     accuracy                           0.99       597
#    macro avg       0.99      0.99      0.99       597
# weighted avg       0.99      0.99      0.99       597

# %% [markdown]
# The classification report shows consistently **high performance across both classes, with precision, recall, and F1-scores all around 0.99**. This indicates that **the model maintains strong predictive capability on unseen data**, with very few misclassifications. The macro and weighted averages are also aligned, **suggesting balanced performance between the two classes and no significant bias**.

# %% [markdown]
# #### Confusion Matrix

# %%
# Printing the Confusion Matrix
display = ConfusionMatrixDisplay(confusion_matrix=conf_matrix_test, display_labels=['0', '1'])
plt.figure(figsize=(8, 6))
display.plot(cmap=plt.cm.Reds)
plt.title('Confusion Matrix Test Set')
plt.show()

# %% [markdown]
# The confusion matrix reveals **only 4 misclassifications out of 597 samples**, which is a very low error rate:
#
# - **1 false positive (class 0 predicted as class 1)**
# - **3 false negatives (class 1 predicted as class 0)**
#
# This confirms that **the model is highly accurate and that both types of errors are minimal and well-balanced**.

# %% [markdown]
# #### ROC and AUC

# %%
# Getting AUC score
auc_score = roc_auc_score(y_true, y_pred)

print(f"AUC: {auc_score:.4f}")

# Calculating FPR, TPR e thresholds
fpr, tpr, thresholds = roc_curve(y_true, y_pred)

# Plot
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2,
         label=f'ROC curve (AUC = {auc_score:.3f})')
plt.plot([0, 1], [0, 1], color='b', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.grid(True, alpha=0.3)
plt.show()
# Out:
# AUC: 0.9934

# %% [markdown]
# The ROC curve is **very close to a perfect square**, indicating strong separability between the classes. The **AUC score of 0.993** reinforces this, **showing that the model has an excellent ability to distinguish between positive and negative classes across different thresholds**.

# %% [markdown]
# ### Predicting Images

# %%
# Number of Exemple Images
repetitions = 5

fig, axes = plt.subplots(1, repetitions, figsize=(4 * repetitions, 4))

# Creating a Map dictionary for the label
classes = { 0 : 'Flipped', 1 : 'Not Flipped'}

for images, labels in dataset_test.take(1):

    for i in range(repetitions):
        ax = axes[i]

        # Add batch dimension
        img = tf.expand_dims(images[i], axis=0)

        # Prediction (logit)
        pred = model.predict(img, verbose=0)

        # Convert logit -> probability -> class
        prob = tf.sigmoid(pred)[0][0]
        predicted_class = int(prob > 0.5)

        ax.imshow(images[i])
        ax.set_title(f"Real: {classes[labels[i].numpy()]} | Pred: {classes[predicted_class]}")
        ax.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# Here, the model is evaluated qualitatively by comparing its predictions against sample images. **The visual inspection shows that the predicted labels are consistent with the true labels from the dataset**, indicating that the model is correctly identifying whether a page is being flipped or not. **This alignment between predictions and ground truth further reinforces the strong performance observed in the quantitative metrics**.
